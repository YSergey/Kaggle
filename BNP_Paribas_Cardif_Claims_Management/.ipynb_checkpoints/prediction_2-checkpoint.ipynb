# %%
import pandas as pd 

dataset = pd.read_csv('./dataset/train.csv')
dataset.head()
# Out:
#    ID  target        v1        v2 v3        v4         v5        v6        v7  \
# 0   3       1  1.335739  8.727474  C  3.921026   7.915266  2.599278  3.176895
# 1   4       1       NaN       NaN  C       NaN   9.191265       NaN       NaN
# 2   5       1  0.943877  5.310079  C  4.410969   5.326159  3.979592  3.928571
# 3   6       1  0.797415  8.304757  C  4.225930  11.627438  2.097700  1.987549
# 4   8       1       NaN       NaN  C       NaN        NaN       NaN       NaN
#
#          v8    ...         v122      v123      v124  v125      v126      v127  \
# 0  0.012941    ...     8.000000  1.989780  0.035754    AU  1.804126  3.113719
# 1  2.301630    ...          NaN       NaN  0.598896    AF       NaN       NaN
# 2  0.019645    ...     9.333333  2.477596  0.013452    AE  1.773709  3.922193
# 3  0.171947    ...     7.018256  1.812795  0.002267    CJ  1.415230  2.954381
# 4       NaN    ...          NaN       NaN       NaN     Z       NaN       NaN
#
#        v128  v129      v130      v131
# 0  2.024285     0  0.636365  2.857144
# 1  1.957825     0       NaN       NaN
# 2  1.120468     2  0.883118  1.176472
# 3  1.990847     1  1.677108  1.034483
# 4       NaN     0       NaN       NaN
#
# [5 rows x 133 columns]

# %%
[col for col in dataset.columns if dataset[col].isnull().sum()>0]
# Out:
# ['v1',
#  'v2',
#  'v3',
#  'v4',
#  'v5',
#  'v6',
#  'v7',
#  'v8',
#  'v9',
#  'v10',
#  'v11',
#  'v12',
#  'v13',
#  'v14',
#  'v15',
#  'v16',
#  'v17',
#  'v18',
#  'v19',
#  'v20',
#  'v21',
#  'v22',
#  'v23',
#  'v25',
#  'v26',
#  'v27',
#  'v28',
#  'v29',
#  'v30',
#  'v31',
#  'v32',
#  'v33',
#  'v34',
#  'v35',
#  'v36',
#  'v37',
#  'v39',
#  'v40',
#  'v41',
#  'v42',
#  'v43',
#  'v44',
#  'v45',
#  'v46',
#  'v48',
#  'v49',
#  'v50',
#  'v51',
#  'v52',
#  'v53',
#  'v54',
#  'v55',
#  'v56',
#  'v57',
#  'v58',
#  'v59',
#  'v60',
#  'v61',
#  'v63',
#  'v64',
#  'v65',
#  'v67',
#  'v68',
#  'v69',
#  'v70',
#  'v73',
#  'v76',
#  'v77',
#  'v78',
#  'v80',
#  'v81',
#  'v82',
#  'v83',
#  'v84',
#  'v85',
#  'v86',
#  'v87',
#  'v88',
#  'v89',
#  'v90',
#  'v91',
#  'v92',
#  'v93',
#  'v94',
#  'v95',
#  'v96',
#  'v97',
#  'v98',
#  'v99',
#  'v100',
#  'v101',
#  'v102',
#  'v103',
#  'v104',
#  'v105',
#  'v106',
#  'v107',
#  'v108',
#  'v109',
#  'v111',
#  'v112',
#  'v113',
#  'v114',
#  'v115',
#  'v116',
#  'v117',
#  'v118',
#  'v119',
#  'v120',
#  'v121',
#  'v122',
#  'v123',
#  'v124',
#  'v125',
#  'v126',
#  'v127',
#  'v128',
#  'v130',
#  'v131']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(dataset.drop(labels=['ID', 'target'], axis=1), dataset['target'],
                                                                                            test_size=.3, random_state=42)

X_train.shape, X_test.shape
# Out:
# ((80024, 131), (34297, 131))

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_vars = list(dataset.select_dtypes(include=numerics).columns)
dataset = dataset[numerical_vars]
dataset.shape
# Out:
# (114321, 114)

# %%
corrmat = X_train.corr()
corrmat = corrmat.abs().unstack()
corrmat = corrmat.sort_values(ascending=False)
corrmat = corrmat[corrmat >= 0.8]
corrmat = corrmat[corrmat <1 ]
corrmat = pd.DataFrame(corrmat).reset_index()
corrmat.columns = ['feature1', 'feature2', 'corr']
corrmat.head()
# Out:
#   feature1 feature2      corr
# 0      v58     v100  0.997622
# 1     v100      v58  0.997622
# 2      v69     v115  0.993573
# 3     v115      v69  0.993573
# 4      v76      v17  0.992519

# %%
grouped_feature_ls = []
correlated_groups = []

for feature in corrmat.feature1.unique():
    if feature not in grouped_feature_ls:
        correlated_block = corrmat[corrmat.feature1 == feature]
        grouped_feature_ls = grouped_feature_ls + list(correlated_block.feature2.unique()) + [feature]
        correlated_groups.append(correlated_block)

print('found {} correlated groups'.format(len(correlated_groups)))
print('out of {} total features'.format(X_train.shape[1]))
# Out:
# found 31 correlated groups
# out of 131 total features

# %%
for group in correlated_groups:
    print(group)
    print('///////////////////////////////')
# Out:
#   feature1 feature2      corr
# 0      v58     v100  0.997622
# ///////////////////////////////
#   feature1 feature2      corr
# 2      v69     v115  0.993573
# ///////////////////////////////
#     feature1 feature2      corr
# 4        v76      v17  0.992519
# 51       v76      v64  0.953521
# 146      v76      v93  0.874306
# 163      v76      v48  0.864467
# ///////////////////////////////
#    feature1 feature2      corr
# 6       v46      v63  0.991654
# 11      v46      v25  0.982290
# 24      v46       v8  0.975250
# 59      v46     v105  0.946311
# 75      v46      v89  0.932277
# 88      v46      v54  0.919460
# ///////////////////////////////
#     feature1 feature2      corr
# 14       v60      v26  0.980771
# 144      v60      v43  0.876529
# 174      v60     v116  0.860019
# ///////////////////////////////
#     feature1 feature2      corr
# 17      v106      v48  0.979785
# 73      v106      v64  0.933384
# 148     v106      v44  0.873250
# 168     v106      v61  0.863056
# 179     v106      v17  0.857544
# 186     v106       v4  0.843085
# 208     v106     v101  0.831800
# ///////////////////////////////
#    feature1 feature2      corr
# 20      v92      v95  0.977029
# ///////////////////////////////
#    feature1 feature2      corr
# 28     v114      v40  0.966816
# 96     v114      v34  0.912230
# ///////////////////////////////
#     feature1 feature2      corr
# 30       v83     v121  0.965890
# 35       v83      v33  0.964379
# 113      v83     v111  0.904244
# 125      v83      v55  0.901733
# 164      v83     v130  0.864264
# 230      v83      v65  0.810230
# ///////////////////////////////
#    feature1 feature2      corr
# 38     v118      v97  0.962499
# ///////////////////////////////
#     feature1 feature2      corr
# 42       v96      v29  0.957529
# 52       v96      v41  0.950015
# 137      v96      v77  0.880527
# 152      v96      v67  0.871379
# ///////////////////////////////
#     feature1 feature2      corr
# 46      v108     v128  0.956805
# 172     v108     v109  0.860977
# 238     v108      v87  0.804461
# ///////////////////////////////
#    feature1 feature2      corr
# 48      v53      v11  0.955597
# ///////////////////////////////
#    feature1 feature2     corr
# 56      v39      v68  0.94688
# ///////////////////////////////
#    feature1 feature2      corr
# 60      v73      v15  0.944885
# 95      v73      v32  0.914744
# ///////////////////////////////
#    feature1 feature2      corr
# 82     v104      v13  0.924087
# ///////////////////////////////
#    feature1 feature2      corr
# 98      v12      v10  0.911819
# ///////////////////////////////
#     feature1 feature2      corr
# 101      v20      v65  0.910674
# ///////////////////////////////
#     feature1 feature2      corr
# 103      v86      v32  0.910089
# 155      v86      v15  0.867503
# ///////////////////////////////
#     feature1 feature2      corr
# 110      v81       v5  0.905419
# 202      v81      v87  0.834392
# 237      v81      v51  0.805052
# ///////////////////////////////
#     feature1 feature2      corr
# 117      v49      v41  0.903874
# 190      v49      v35  0.840899
# 196      v49      v67  0.836860
# ///////////////////////////////
#     feature1 feature2    corr
# 126      v37       v1  0.8937
# ///////////////////////////////
#     feature1 feature2      corr
# 134     v124     v105  0.882847
# 215     v124      v54  0.823849
# 226     v124      v25  0.812545
# ///////////////////////////////
#     feature1 feature2     corr
# 166     v119     v123  0.86335
# ///////////////////////////////
#     feature1 feature2      corr
# 176      v94     v103  0.858828
# 194      v94     v126  0.840640
# ///////////////////////////////
#     feature1 feature2      corr
# 182      v98      v70  0.846104
# ///////////////////////////////
#     feature1 feature2      corr
# 192      v84      v80  0.840893
# 240      v84      v33  0.804186
# ///////////////////////////////
#     feature1 feature2      corr
# 198       v9     v122  0.836543
# ///////////////////////////////
#     feature1 feature2      corr
# 204      v14      v21  0.833696
# ///////////////////////////////
#     feature1 feature2      corr
# 234       v7      v95  0.805629
# ///////////////////////////////
#     feature1 feature2      corr
# 242      v78      v16  0.800902
# ///////////////////////////////

# %%
group = correlated_groups[2]
group
# Out:
#     feature1 feature2      corr
# 4        v76      v17  0.992519
# 51       v76      v64  0.953521
# 146      v76      v93  0.874306
# 163      v76      v48  0.864467

# %%
from sklearn.ensemble import RandomForestClassifier

features = list(group.feature2.unique())+['v17']
rf = RandomForestClassifier(n_estimators=200, random_state=39, max_depth=4)
rf.fit(X_train[features].fillna(0), y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=4, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#             oob_score=False, random_state=39, verbose=0, warm_start=False)

# %%
importance = pd.concat(
    [pd.Series(features),
     pd.Series(rf.feature_importances_)], axis=1)

importance.columns = ['feature', 'importance']
importance.sort_values(by='importance', ascending=False)
# Out:
#   feature  importance
# 3     v48    0.375427
# 2     v93    0.166766
# 0     v17    0.155322
# 1     v64    0.151751
# 4     v17    0.150734
